# %%
import cv2
import matplotlib.pyplot as plt
img=cv2.imread("C:/Users/subha/Downloads/lena_rgb.png")
plt.imshow(img)
print(cv2.__version__)
# Out:
# 4.10.0

# %%
img.shape
# Out:
# (512, 512, 3)

# %%
img.size
# Out:
# 786432

# %%
img
# Out:
# array([[[125, 137, 226],
#         [125, 137, 226],
#         [133, 137, 223],
#         ...,
#         [122, 148, 230],
#         [110, 130, 221],
#         [ 90,  99, 200]],
#
#        [[125, 137, 226],
#         [125, 137, 226],
#         [133, 137, 223],
#         ...,
#         [122, 148, 230],
#         [110, 130, 221],
#         [ 90,  99, 200]],
#
#        [[125, 137, 226],
#         [125, 137, 226],
#         [133, 137, 223],
#         ...,
#         [122, 148, 230],
#         [110, 130, 221],
#         [ 90,  99, 200]],
#
#        ...,
#
#        [[ 60,  18,  84],
#         [ 60,  18,  84],
#         [ 58,  27,  92],
#         ...,
#         [ 84,  73, 173],
#         [ 76,  68, 172],
#         [ 79,  62, 177]],
#
#        [[ 57,  22,  82],
#         [ 57,  22,  82],
#         [ 62,  32,  96],
#         ...,
#         [ 79,  70, 179],
#         [ 81,  71, 181],
#         [ 81,  74, 185]],
#
#        [[ 57,  22,  82],
#         [ 57,  22,  82],
#         [ 62,  32,  96],
#         ...,
#         [ 79,  70, 179],
#         [ 81,  71, 181],
#         [ 81,  74, 185]]], dtype=uint8)

# %%
RGB_img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(RGB_img)

# %%
RGB_img.shape
# Out:
# (512, 512, 3)

# %%
RGB_img.size
# Out:
# 786432

# %%
RGB_img
# Out:
# array([[[226, 137, 125],
#         [226, 137, 125],
#         [223, 137, 133],
#         ...,
#         [230, 148, 122],
#         [221, 130, 110],
#         [200,  99,  90]],
#
#        [[226, 137, 125],
#         [226, 137, 125],
#         [223, 137, 133],
#         ...,
#         [230, 148, 122],
#         [221, 130, 110],
#         [200,  99,  90]],
#
#        [[226, 137, 125],
#         [226, 137, 125],
#         [223, 137, 133],
#         ...,
#         [230, 148, 122],
#         [221, 130, 110],
#         [200,  99,  90]],
#
#        ...,
#
#        [[ 84,  18,  60],
#         [ 84,  18,  60],
#         [ 92,  27,  58],
#         ...,
#         [173,  73,  84],
#         [172,  68,  76],
#         [177,  62,  79]],
#
#        [[ 82,  22,  57],
#         [ 82,  22,  57],
#         [ 96,  32,  62],
#         ...,
#         [179,  70,  79],
#         [181,  71,  81],
#         [185,  74,  81]],
#
#        [[ 82,  22,  57],
#         [ 82,  22,  57],
#         [ 96,  32,  62],
#         ...,
#         [179,  70,  79],
#         [181,  71,  81],
#         [185,  74,  81]]], dtype=uint8)

# %%
gray_image = cv2.cvtColor(RGB_img,cv2.COLOR_RGB2GRAY)
plt.imshow(gray_image,cmap='gray')

# %%
gray_image.shape
# Out:
# (512, 512)

# %%
gray_image
# Out:
# array([[162, 162, 162, ..., 170, 155, 128],
#        [162, 162, 162, ..., 170, 155, 128],
#        [162, 162, 162, ..., 170, 155, 128],
#        ...,
#        [ 43,  43,  50, ..., 104, 100,  98],
#        [ 44,  44,  55, ..., 104, 105, 108],
#        [ 44,  44,  55, ..., 104, 105, 108]], dtype=uint8)

# %%
import seaborn as sns
equalized_image = cv2.equalizeHist(gray_image)

plt.figure(figsize=(12, 6))

plt.subplot(2, 2, 1)
plt.imshow(gray_image, cmap='gray')
plt.axis('off')
plt.title('Original Grayscale Image')

plt.subplot(2, 2, 2)
sns.histplot(gray_image.ravel(), bins=30, kde=True, color='skyblue', alpha=0.6)
plt.title('Histogram of Original Image')
plt.xlim([0, 256])

plt.subplot(2, 2, 3)
plt.imshow(equalized_image, cmap='gray')
plt.axis('off')
plt.title('Equalized Image')

plt.subplot(2, 2, 4)
sns.histplot(equalized_image.ravel(), bins=30, kde=True, color='skyblue', alpha=0.6)
plt.title('Histogram of Equalized Image')
plt.xlim([0, 256])

plt.tight_layout()
plt.show()

# %%
equalized_image.shape
# Out:
# (512, 512)

# %%
import cv2
import matplotlib.pyplot as plt

# Read the image
img = cv2.imread("C:/Users/subha/Downloads/lena_rgb.png")

resized_img = cv2.resize(img, (256, 256))

resized_img_rgb = cv2.cvtColor(resized_img, cv2.COLOR_BGR2RGB)

print('After resizing :')
print(resized_img_rgb.size)

plt.imshow(resized_img_rgb)
plt.axis()  
plt.show()
# Out:
# After resizing :
# 196608

# %% [markdown]
# ### Without Using Function

# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt



image_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

R = image_rgb[:, :, 0]
G = image_rgb[:, :, 1]
B = image_rgb[:, :, 2]

# Apply the grayscale conversion formula: Y = 0.2989*R + 0.5870*G + 0.1140*B
gray_image1 = 0.2989 * R + 0.5870 * G + 0.1140 * B

# Convert the result to an integer type (0-255 range)
#gray_image = np.uint8(gray_image)

# Save or display the grayscale image
#cv2.imwrite('grayscale_image.jpg', gray_image)
plt.imshow(gray_image1,cmap='gray')
#cv2.waitKey(0)
#cv2.destroyAllWindows()

# %%
#histogram, bins = np.histogram(gray_image.flatten(), bins=256, range=[0, 256])

cdf = histogram.cumsum()
cdf_normalized = cdf * 255 / cdf[-1]  
equalized_image = np.interp(gray_image.flatten(), bins[:-1], cdf_normalized).reshape(gray_image.shape).astype(np.uint8)
plt.figure(figsize=(12, 6))

plt.subplot(2, 2, 1)
plt.imshow(gray_image, cmap='gray')
plt.axis('off')
plt.title('Original Grayscale Image')

plt.subplot(2, 2, 2)
sns.histplot(gray_image.ravel(), bins=30, kde=True, color='skyblue', alpha=0.6)
plt.title('Histogram of Original Image')
plt.xlim([0, 256])

plt.subplot(2, 2, 3)
plt.imshow(equalized_image, cmap='gray')
plt.axis('off')
plt.title('Equalized Image')

plt.subplot(2, 2, 4)
sns.histplot(equalized_image.ravel(), bins=30, kde=True, color='skyblue', alpha=0.6)
plt.title('Histogram of Equalized Image')
plt.xlim([0, 256])

plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[16], line 3
#       1 #histogram, bins = np.histogram(gray_image.flatten(), bins=256, range=[0, 256])
# ----> 3 cdf = histogram.cumsum()
#       4 cdf_normalized = cdf * 255 / cdf[-1]
#       5 equalized_image = np.interp(gray_image.flatten(), bins[:-1], cdf_normalized).reshape(gray_image.shape).astype(np.uint8)
#
# NameError: name 'histogram' is not defined
